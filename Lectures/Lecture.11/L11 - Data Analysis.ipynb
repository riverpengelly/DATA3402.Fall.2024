# %% [markdown]
# # Lecture 11
#
# For the next few lectures, we are going to work on a basic data analysis problem: grading a class. We will first use pandas to compute grades. Then we will build a grading book system.

# %% [markdown]
# ## Data Analysis (scripting/notebook)
#
# ### Data Preperation
#
# We'll use pandas to read in some grade data. The file we are reading is a CSV dump of a Google Sheet from a TA grading a course. As we soon will see, the file is not properly formatted, and as often is the case, we will have to do a bit of manipulation before the data is usably in memory.

# %%
import pandas as pd

# %%
# !ls -lh
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Before we read in the file, lets take a look.

# %%
# !cat Data-1401-Grades.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Data Manipulation with Command-line Tools and Pandas
#
# The file is the CSV export of a google sheet, which isn't ideally formatted:
# * First line is the grading rubric, not the column names.
# * Lines alternate between the grade and the comments for the specific lab/exam.
# * The exam grades are in the format XX-sent.
#
# Reading the file with a CSV reader therefore isn't going to get table in the right format:

# %%
df = pd.read_csv("Data-1401-Grades.csv")

# %%
df
# Out:
#                          No attempt: -5,wrong:-1...-5  \
# 0                                               Lab 1
# 1                                                 NaN
# 2                                         no solution
# 3                                                 100
# 4                                   Completed the lab
# 5                                                 100
# 6                                   Completed the lab
# 7                                                  93
# 8   ex4 - attempted, wrong answer(-2)\nex5c - not ...
# 9                                                   0
# 10                                        no solution
# 11                                                 95
# 12                -ex5c missing(-5)
# 13                                                100
# 14                                  completed the lab
# 15                                                 95
# 16                                  -ex5c missing(-5)
# 17                                                 95
# 18                                  -ex5c missing(-5)
# 19                                                  0
# 20                                        no solution
# 21                                                  0
# 22                                        no solution
# 23                                                 95
# 24                                  ex 5c missing(-5)
# 25                                                 98
# 26                 ex 4 attempted but not correct(-2)
# 27                                                 93
# 28          ex3 attempted no solution, 5c missing(-7)
# 29                                                100
# 30                                          completed
# 31                                                 95
# 32                                  ex 5c missing(-5)
#
#                             No attempt: -5, wrong: -2  \
# 0                                               Lab 2
# 1                                                   0
# 2                                         no solution
# 3                                                  96
# 4   ex4- attempted,wrong solution -2\nex8 -wrong s...
# 5                                                 100
# 6                           Completed the whole lab\n
# 7                                                 100
# 8                             Completed the whole lab
# 9                                                  81
# 10  ex2-attempted(empty list) -2\nex3 - no solutio...
# 11                                                100
# 12                            Completed the whole lab
# 13                                                 98
# 14  ex10 - attempted, solution wrong(nameerror-gue...
# 15                                                 98
# 16  ex8 - wrong solution, sequence should be 1,1,....
# 17                                                 96
# 18  ex8 - should start from 1 as given in the ques...
# 19                                                 78
# 20  ex1 - 1 function(odd) missing -2\nex2 - no sol...
# 21                                                 76
# 22  ex1 - syntax error -2\nex3 - wrong solution -2...
# 23                                                 89
# 24  ex7 - condition not working on rock and scisso...
# 25                                                 94
# 26  ex3 - wrong solution(attempted) -2\nex4 - wron...
# 27                                                 77
# 28  ex3 - should have taken list of numbers as in ...
# 29                                                 96
# 30  ex8 - Sequence should have started from 1 as g...
# 31                                                 94
# 32  ex3 - incomplete function -3\nex10 - incomplet...
#
#                        No attempt: -10, wrong: -1..-7  \
# 0                                               Lab 3
# 1                                                   0
# 2                             -did not submit the Lab
# 3                                                  46
# 4   ex1 - Nameerror get_size() is not defined(-2)\...
# 5                                                  90
# 6    ex10 - not attempted (-10)\nex11 - not attempted
# 7                                                  24
# 8   ex2 - returns 1 for winner_2, returns 1 for no...
# 9                                                   0
# 10                           - did not submit the lab
# 11                                                105
# 12         ex5 - does not draw board (-5)\nex11 - +10
# 13                                                 87
# 14  ex2 - flips for condition 'also_no_winner' ret...
# 15                                                 50
# 16  ex1 - works for only 1 condition, does not ret...
# 17                                                 98
# 18  ex5 - does not return True or False(-2)\nex11 ...
# 19                                                 37
# 20  ex1 - Nameerror "game_board" not defined (-2)\...
# 21                                                NaN
# 22                                                NaN
# 23                                                  0
# 24                            -did not submit the Lab
# 25                                                 35
# 26  ex2 - does not return  -1, 0, 1, or 2 , return...
# 27                                                 23
# 28  ex2 - returns 1 instead of 0 for "no_winner" (...
# 29                                                 88
# 30  ex5 - does not return True or False(-2)\nex9 -...
# 31                                                 60
# 32  ex7- not attempted\nex8- not attempted\nex9- n...
#
#             No attempt: -10, wrong: -1 ..-8. no bonus  \
# 0                                               Lab 4
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6               ex8-not attempted\nex9- not attempted
# 7                                                 NaN
# 8                                                 NaN
# 9                                                   0
# 10                            -did not submit the lab
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                  0
# 24                            -did not submit the Lab
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  ex7 -not attempted\nex8- not attempted\nex9- n...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                       No attempt: -25, wrong: -1..-20  \
# 0                                              Exam 1
# 1                                                   0
# 2                             did not submit the exam
# 3                                             68-sent
# 4   q1c - does not return the list instead returns...
# 5                                             88-sent
# 6   note - try to use better variable names\nq3b -...
# 7                                             96-sent
# 8   note- try not to use names which are built-in ...
# 9                                             43-sent
# 10  q1b - returns the index 0 instead of 23 as men...
# 11                                            96-sent
# 12  q4b - Implementation correct , gives NameError...
# 13                                            89-sent
# 14  q3a - did not print the result(-2)\nq3b- solut...
# 15                                                 52
# 16  q1a,q1b,q1c - incomplete function. Does not ha...
# 17                                           100-sent
# 18                                          excellent
# 19                                                 67
# 20  -Late submission -10\nq1b - Nameerror  (-3)\nq...
# 21                                                  0
# 22                           -did not submit the exam
# 23                                            66-sent
# 24  q2- should not be using numpy(built in functio...
# 25                                            96-sent
# 26  q2- Right logic but not commented well, commen...
# 27                                            64-sent
# 28  q1a - You had to return just the string "Alaba...
# 29                                            64-sent
# 30  q1a - return just the string, not in list form...
# 31                                            98-sent
# 32  q4b - pair() is not working properly for few t...
#
#    No attempt: -14, wrong: -1..-12, bonus 0..14  \
# 0                                         Lab 5
# 1                                             0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
#
#     No attempt: -15, wrong: -1..-12, bonus 0..5  \
# 0                                           NaN
# 1                                           0.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
#
#    No attempt: -14, wrong: -1..-12 Unnamed: 8
# 0                            Lab 7     Exam 2
# 1                                0          0
# 2                              NaN        NaN
# 3                              NaN        NaN
# 4                              NaN        NaN
# 5                              NaN        NaN
# 6                              NaN        NaN
# 7                              NaN        NaN
# 8                              NaN        NaN
# 9                              NaN        NaN
# 10                             NaN        NaN
# 11                             NaN        NaN
# 12                             NaN        NaN
# 13                             NaN        NaN
# 14                             NaN        NaN
# 15                             NaN        NaN
# 16                             NaN        NaN
# 17                             NaN        NaN
# 18                             NaN        NaN
# 19                             NaN        NaN
# 20                             NaN        NaN
# 21                             NaN        NaN
# 22                             NaN        NaN
# 23                             NaN        NaN
# 24                             NaN        NaN
# 25                             NaN        NaN
# 26                             NaN        NaN
# 27                             NaN        NaN
# 28                             NaN        NaN
# 29                             NaN        NaN
# 30                             NaN        NaN
# 31                             NaN        NaN
# 32                             NaN        NaN

# %% [markdown]
# Let's start fixing these issues. First we can just drop the first line. There are lots of ways of doing so... easiest would be to use some of the command line unix utilities we became familiar with in the beginning of the course. First, let's count the lines:

# %%
# !wc -l Data-1401-grades.csv
# Out:
# 'wc' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# We can use the unix command `tail` to write out the lasn n lines of a file... let's use it to drop the first line:

# %%
# !tail -179 Data-1401-Grades.csv
# Out:
# 'tail' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# We can use unix redirection to write the output into another file:

# %%
# !tail -179 Data-1401-Grades.csv > Data-1401-Grades-Fixed.csv
# Out:
# 'tail' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Let's see the result:

# %%
# !cat Data-1401-Grades-Fixed.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# Let's Try reading the new file now:

# %%
df = pd.read_csv("Data-1401-Grades-Fixed.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv("Data-1401-Grades-Fixed.csv")
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
df
# Out:
#                          No attempt: -5,wrong:-1...-5  \
# 0                                               Lab 1
# 1                                                 NaN
# 2                                         no solution
# 3                                                 100
# 4                                   Completed the lab
# 5                                                 100
# 6                                   Completed the lab
# 7                                                  93
# 8   ex4 - attempted, wrong answer(-2)\nex5c - not ...
# 9                                                   0
# 10                                        no solution
# 11                                                 95
# 12                -ex5c missing(-5)
# 13                                                100
# 14                                  completed the lab
# 15                                                 95
# 16                                  -ex5c missing(-5)
# 17                                                 95
# 18                                  -ex5c missing(-5)
# 19                                                  0
# 20                                        no solution
# 21                                                  0
# 22                                        no solution
# 23                                                 95
# 24                                  ex 5c missing(-5)
# 25                                                 98
# 26                 ex 4 attempted but not correct(-2)
# 27                                                 93
# 28          ex3 attempted no solution, 5c missing(-7)
# 29                                                100
# 30                                          completed
# 31                                                 95
# 32                                  ex 5c missing(-5)
#
#                             No attempt: -5, wrong: -2  \
# 0                                               Lab 2
# 1                                                   0
# 2                                         no solution
# 3                                                  96
# 4   ex4- attempted,wrong solution -2\nex8 -wrong s...
# 5                                                 100
# 6                           Completed the whole lab\n
# 7                                                 100
# 8                             Completed the whole lab
# 9                                                  81
# 10  ex2-attempted(empty list) -2\nex3 - no solutio...
# 11                                                100
# 12                            Completed the whole lab
# 13                                                 98
# 14  ex10 - attempted, solution wrong(nameerror-gue...
# 15                                                 98
# 16  ex8 - wrong solution, sequence should be 1,1,....
# 17                                                 96
# 18  ex8 - should start from 1 as given in the ques...
# 19                                                 78
# 20  ex1 - 1 function(odd) missing -2\nex2 - no sol...
# 21                                                 76
# 22  ex1 - syntax error -2\nex3 - wrong solution -2...
# 23                                                 89
# 24  ex7 - condition not working on rock and scisso...
# 25                                                 94
# 26  ex3 - wrong solution(attempted) -2\nex4 - wron...
# 27                                                 77
# 28  ex3 - should have taken list of numbers as in ...
# 29                                                 96
# 30  ex8 - Sequence should have started from 1 as g...
# 31                                                 94
# 32  ex3 - incomplete function -3\nex10 - incomplet...
#
#                        No attempt: -10, wrong: -1..-7  \
# 0                                               Lab 3
# 1                                                   0
# 2                             -did not submit the Lab
# 3                                                  46
# 4   ex1 - Nameerror get_size() is not defined(-2)\...
# 5                                                  90
# 6    ex10 - not attempted (-10)\nex11 - not attempted
# 7                                                  24
# 8   ex2 - returns 1 for winner_2, returns 1 for no...
# 9                                                   0
# 10                           - did not submit the lab
# 11                                                105
# 12         ex5 - does not draw board (-5)\nex11 - +10
# 13                                                 87
# 14  ex2 - flips for condition 'also_no_winner' ret...
# 15                                                 50
# 16  ex1 - works for only 1 condition, does not ret...
# 17                                                 98
# 18  ex5 - does not return True or False(-2)\nex11 ...
# 19                                                 37
# 20  ex1 - Nameerror "game_board" not defined (-2)\...
# 21                                                NaN
# 22                                                NaN
# 23                                                  0
# 24                            -did not submit the Lab
# 25                                                 35
# 26  ex2 - does not return  -1, 0, 1, or 2 , return...
# 27                                                 23
# 28  ex2 - returns 1 instead of 0 for "no_winner" (...
# 29                                                 88
# 30  ex5 - does not return True or False(-2)\nex9 -...
# 31                                                 60
# 32  ex7- not attempted\nex8- not attempted\nex9- n...
#
#             No attempt: -10, wrong: -1 ..-8. no bonus  \
# 0                                               Lab 4
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6               ex8-not attempted\nex9- not attempted
# 7                                                 NaN
# 8                                                 NaN
# 9                                                   0
# 10                            -did not submit the lab
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                  0
# 24                            -did not submit the Lab
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  ex7 -not attempted\nex8- not attempted\nex9- n...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                       No attempt: -25, wrong: -1..-20  \
# 0                                              Exam 1
# 1                                                   0
# 2                             did not submit the exam
# 3                                             68-sent
# 4   q1c - does not return the list instead returns...
# 5                                             88-sent
# 6   note - try to use better variable names\nq3b -...
# 7                                             96-sent
# 8   note- try not to use names which are built-in ...
# 9                                             43-sent
# 10  q1b - returns the index 0 instead of 23 as men...
# 11                                            96-sent
# 12  q4b - Implementation correct , gives NameError...
# 13                                            89-sent
# 14  q3a - did not print the result(-2)\nq3b- solut...
# 15                                                 52
# 16  q1a,q1b,q1c - incomplete function. Does not ha...
# 17                                           100-sent
# 18                                          excellent
# 19                                                 67
# 20  -Late submission -10\nq1b - Nameerror  (-3)\nq...
# 21                                                  0
# 22                           -did not submit the exam
# 23                                            66-sent
# 24  q2- should not be using numpy(built in functio...
# 25                                            96-sent
# 26  q2- Right logic but not commented well, commen...
# 27                                            64-sent
# 28  q1a - You had to return just the string "Alaba...
# 29                                            64-sent
# 30  q1a - return just the string, not in list form...
# 31                                            98-sent
# 32  q4b - pair() is not working properly for few t...
#
#    No attempt: -14, wrong: -1..-12, bonus 0..14  \
# 0                                         Lab 5
# 1                                             0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
#
#     No attempt: -15, wrong: -1..-12, bonus 0..5  \
# 0                                           NaN
# 1                                           0.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
#
#    No attempt: -14, wrong: -1..-12 Unnamed: 8
# 0                            Lab 7     Exam 2
# 1                                0          0
# 2                              NaN        NaN
# 3                              NaN        NaN
# 4                              NaN        NaN
# 5                              NaN        NaN
# 6                              NaN        NaN
# 7                              NaN        NaN
# 8                              NaN        NaN
# 9                              NaN        NaN
# 10                             NaN        NaN
# 11                             NaN        NaN
# 12                             NaN        NaN
# 13                             NaN        NaN
# 14                             NaN        NaN
# 15                             NaN        NaN
# 16                             NaN        NaN
# 17                             NaN        NaN
# 18                             NaN        NaN
# 19                             NaN        NaN
# 20                             NaN        NaN
# 21                             NaN        NaN
# 22                             NaN        NaN
# 23                             NaN        NaN
# 24                             NaN        NaN
# 25                             NaN        NaN
# 26                             NaN        NaN
# 27                             NaN        NaN
# 28                             NaN        NaN
# 29                             NaN        NaN
# 30                             NaN        NaN
# 31                             NaN        NaN
# 32                             NaN        NaN

# %% [markdown]
# Now we have to deal with the problem that every other line contains information we don't need. For example:

# %%
df["Lab 1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lab 1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df["Lab 1"]
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Lab 1'

# %% [markdown]
# The data is now in memory stored as a data frame. Let's take a few minutes and go over the features of DataFrame from the Pandas documentation:
#
# * [Pandas Data Structures](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#dsintro)
# * [Pandas DataFrame in 10 minutes](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)

# %% [markdown]
# We can deal with the 'every-other-line" problem by using Pandas to create a new DataFrame from select row of our existing DataFrame using Boolean indexing. Basically, if you use index a DataFrame with a list of booleans with the same length as the number of rows in the DataFrame, it'll use the booleans to select the rows. So we need a list containing of laternating True/False booleans:

# %%
mask = list()
for i in range(16):
	mask.append(True)
	mask.append(False)
mask
# Out:
# [True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False]

# %%
df_0 = df[mask]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22864\1353392656.py in ?()
# ----> 1 df_0 = df[mask]
#
# c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
# -> 4093             return self._getitem_bool_array(key)
#    4094
#    4095         # We are left with two options: a single key, and a collection of keys,
#    4096         # We interpret tuples as collections only for non-MultiIndex
#
# c:\Users\helix\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4139                 UserWarning,
#    4140                 stacklevel=find_stack_level(),
#    4141             )
#    4142         elif len(key) != len(self.index):
# -> 4143             raise ValueError(
#    4144                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    4145             )
#    4146
#
# ValueError: Item wrong length 32 instead of 33.

# %%
df_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_0
#
# NameError: name 'df_0' is not defined

# %% [markdown]
# Next, we have to fix the "Exam 1" column and remove "-sent" from it. Here's the plan:
#
# * Ask DataFrame for the column
# * Convert Column into a list.
# * Fix Every item of the list
# 	* Remove "-sent"
# 	* Convert to int (from string)
# * Add back the fixed list as a new column.

# %%
# 1
df_0["Exam 1"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # 1
# ----> 2 df_0["Exam 1"]
#
# NameError: name 'df_0' is not defined

# %%
# 2
df_0["Exam 1"].tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # 2
# ----> 2 df_0["Exam 1"].tolist()
#
# NameError: name 'df_0' is not defined

# %%
#3A
list(map(lambda x: x.split("-")[0], df_0["Exam 1"].tolist()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #3A
# ----> 2 list(map(lambda x: x.split("-")[0], df_0["Exam 1"].tolist()))
#
# NameError: name 'df_0' is not defined

# %%
# 3B
list(map(lambda x: int(x.split("-")[0]), df_0["Exam 1"].tolist()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # 3B
# ----> 2 list(map(lambda x: int(x.split("-")[0]), df_0["Exam 1"].tolist()))
#
# NameError: name 'df_0' is not defined

# %%
# 4
df_0["Exam 1 Fixed"] = list(map(lambda x: int(x.split("-")[0]), df_0["Exam 1"].tolist()))

# %%
df_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_0
#
# NameError: name 'df_0' is not defined

# %% [markdown]
# We finally have the exam data in a `DataFrame` in a way we can use it:

# %%
df_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_0
#
# NameError: name 'df_0' is not defined

# %% [markdown]
# ## Data Visualization / Analysis
#
# First thing, make a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(df_0["exam 1 Fixed"], bins = 40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 4 plt.hist(df_0["exam 1 Fixed"], bins = 40)
#
# NameError: name 'df_0' is not defined

# %%
df_0["Exam 1 Fixed"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df_0["Exam 1 Fixed"]
#
# NameError: name 'df_0' is not defined

# %%
import numpy as np
print("Mean:", np.mean(df_0["Exam 1 Fixed"]))
